# %%
import pandas as pd
import numpy as np

# %%
ENG_BAT= pd.read_html('https://stats.espncricinfo.com/ci/engine/records/batting/most_runs_career.html?id=14450;team=1;type=tournament')

# %%
eng_bat = ENG_BAT[0]

# %%
eng_bat
# Out:
#            Player  Mat  Inns  NO  Runs   HS    Ave   BF      SR  100  50  0  \
# 0      JC Buttler    6     6   1   225  80*  45.00  156  144.23    0   2  1
# 1        AD Hales    6     6   1   212  86*  42.40  144  147.22    0   2  0
# 2       BA Stokes    6     5   2   110  52*  36.66  104  105.76    0   1  0
# 3          MM Ali    6     5   2    57  24*  19.00   46  123.91    0   0  0
# 4        DJ Malan    4     3   1    56   35  28.00   68   82.35    0   0  0
# 5        HC Brook    6     5   0    56   20  11.20   58   96.55    0   0  0
# 6  LS Livingstone    6     5   3    55  29*  27.50   44  125.00    0   0  0
# 7       SM Curran    6     2   1    12   6*  12.00   14   85.71    0   0  0
# 8         PD Salt    2     1   0    10   10  10.00    9  111.11    0   0  0
# 9       CR Woakes    6     1   1     5   5*      -    3  166.66    0   0  0
#
#    4s  6s
# 0  24   7
# 1  19  10
# 2   7   1
# 3   6   1
# 4   2   0
# 5   2   1
# 6   4   1
# 7   0   1
# 8   2   0
# 9   1   0

# %%
eng_bat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  10 non-null     object
#  1   Mat     10 non-null     int64
#  2   Inns    10 non-null     int64
#  3   NO      10 non-null     int64
#  4   Runs    10 non-null     int64
#  5   HS      10 non-null     object
#  6   Ave     10 non-null     object
#  7   BF      10 non-null     int64
#  8   SR      10 non-null     float64
#  9   100     10 non-null     int64
#  10  50      10 non-null     int64
#  11  0       10 non-null     int64
#  12  4s      10 non-null     int64
#  13  6s      10 non-null     int64
# dtypes: float64(1), int64(10), object(3)
# memory usage: 1.2+ KB

# %%
eng_bat.shape
# Out:
# (10, 14)

# %%
eng_bat.drop(9,axis = 0,inplace = True)

# %%
eng_bat
# Out:
#            Player  Mat  Inns  NO  Runs   HS    Ave   BF      SR  100  50  0  \
# 0      JC Buttler    6     6   1   225  80*  45.00  156  144.23    0   2  1
# 1        AD Hales    6     6   1   212  86*  42.40  144  147.22    0   2  0
# 2       BA Stokes    6     5   2   110  52*  36.66  104  105.76    0   1  0
# 3          MM Ali    6     5   2    57  24*  19.00   46  123.91    0   0  0
# 4        DJ Malan    4     3   1    56   35  28.00   68   82.35    0   0  0
# 5        HC Brook    6     5   0    56   20  11.20   58   96.55    0   0  0
# 6  LS Livingstone    6     5   3    55  29*  27.50   44  125.00    0   0  0
# 7       SM Curran    6     2   1    12   6*  12.00   14   85.71    0   0  0
# 8         PD Salt    2     1   0    10   10  10.00    9  111.11    0   0  0
#
#    4s  6s
# 0  24   7
# 1  19  10
# 2   7   1
# 3   6   1
# 4   2   0
# 5   2   1
# 6   4   1
# 7   0   1
# 8   2   0

# %%
#  eng_bat.iloc[9].drop()   doubt

# %%
new_col = eng_bat['HS'].str.replace('*','',regex=True)

# %%
eng_bat['HS'] = new_col

# %%
eng_bat
# Out:
#            Player  Mat  Inns  NO  Runs  HS    Ave   BF      SR  100  50  0  \
# 0      JC Buttler    6     6   1   225  80  45.00  156  144.23    0   2  1
# 1        AD Hales    6     6   1   212  86  42.40  144  147.22    0   2  0
# 2       BA Stokes    6     5   2   110  52  36.66  104  105.76    0   1  0
# 3          MM Ali    6     5   2    57  24  19.00   46  123.91    0   0  0
# 4        DJ Malan    4     3   1    56  35  28.00   68   82.35    0   0  0
# 5        HC Brook    6     5   0    56  20  11.20   58   96.55    0   0  0
# 6  LS Livingstone    6     5   3    55  29  27.50   44  125.00    0   0  0
# 7       SM Curran    6     2   1    12   6  12.00   14   85.71    0   0  0
# 8         PD Salt    2     1   0    10  10  10.00    9  111.11    0   0  0
#
#    4s  6s
# 0  24   7
# 1  19  10
# 2   7   1
# 3   6   1
# 4   2   0
# 5   2   1
# 6   4   1
# 7   0   1
# 8   2   0

# %%
eng_bat['Team'] = 'ENG'

# %%
eng_bat
# Out:
#            Player  Mat  Inns  NO  Runs  HS    Ave   BF      SR  100  50  0  \
# 0      JC Buttler    6     6   1   225  80  45.00  156  144.23    0   2  1
# 1        AD Hales    6     6   1   212  86  42.40  144  147.22    0   2  0
# 2       BA Stokes    6     5   2   110  52  36.66  104  105.76    0   1  0
# 3          MM Ali    6     5   2    57  24  19.00   46  123.91    0   0  0
# 4        DJ Malan    4     3   1    56  35  28.00   68   82.35    0   0  0
# 5        HC Brook    6     5   0    56  20  11.20   58   96.55    0   0  0
# 6  LS Livingstone    6     5   3    55  29  27.50   44  125.00    0   0  0
# 7       SM Curran    6     2   1    12   6  12.00   14   85.71    0   0  0
# 8         PD Salt    2     1   0    10  10  10.00    9  111.11    0   0  0
#
#    4s  6s Team
# 0  24   7  ENG
# 1  19  10  ENG
# 2   7   1  ENG
# 3   6   1  ENG
# 4   2   0  ENG
# 5   2   1  ENG
# 6   4   1  ENG
# 7   0   1  ENG
# 8   2   0  ENG

# %%
eng_bat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  9 non-null      object
#  1   Mat     9 non-null      int64
#  2   Inns    9 non-null      int64
#  3   NO      9 non-null      int64
#  4   Runs    9 non-null      int64
#  5   HS      9 non-null      object
#  6   Ave     9 non-null      object
#  7   BF      9 non-null      int64
#  8   SR      9 non-null      float64
#  9   100     9 non-null      int64
#  10  50      9 non-null      int64
#  11  0       9 non-null      int64
#  12  4s      9 non-null      int64
#  13  6s      9 non-null      int64
#  14  Team    9 non-null      object
# dtypes: float64(1), int64(10), object(4)
# memory usage: 1.2+ KB

# %%
eng_bat['HS'] = eng_bat['HS'].astype("int64")

# %%
eng_bat['Ave'] = eng_bat['Ave'].astype("float64")

# %%
eng_bat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  9 non-null      object
#  1   Mat     9 non-null      int64
#  2   Inns    9 non-null      int64
#  3   NO      9 non-null      int64
#  4   Runs    9 non-null      int64
#  5   HS      9 non-null      int64
#  6   Ave     9 non-null      float64
#  7   BF      9 non-null      int64
#  8   SR      9 non-null      float64
#  9   100     9 non-null      int64
#  10  50      9 non-null      int64
#  11  0       9 non-null      int64
#  12  4s      9 non-null      int64
#  13  6s      9 non-null      int64
#  14  Team    9 non-null      object
# dtypes: float64(2), int64(11), object(2)
# memory usage: 1.2+ KB

# %%
df = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/batting/most_runs_career.html?id=14450;team=6;type=tournament')

# %%
ind_bat = df[0]

# %%
ind_bat
# Out:
#             Player  Mat  Inns  NO  Runs   HS    Ave   BF      SR  100  50  0  \
# 0          V Kohli    6     6   3   296  82*  98.66  217  136.40    0   4  0
# 1         SA Yadav    6     6   2   239   68  59.75  126  189.68    0   3  0
# 2        HH Pandya    6     5   0   128   63  25.60   97  131.95    0   1  0
# 3         KL Rahul    6     6   0   128   51  21.33  106  120.75    0   2  0
# 4        RG Sharma    6     6   0   116   53  19.33  109  106.42    0   1  0
# 5         R Ashwin    6     4   3    21  13*  21.00   18  116.66    0   0  0
# 6       KD Karthik    4     3   0    14    7   4.66   22   63.63    0   0  0
# 7          RR Pant    2     2   0     9    6   4.50    9  100.00    0   0  0
# 8         AR Patel    5     3   1     9    7   4.50    9  100.00    0   0  0
# 9          B Kumar    6     1   1     4   4*      -    6   66.66    0   0  0
# 10  Arshdeep Singh    6     1   1     2   2*      -    1  200.00    0   0  0
# ...

# %%
ind_bat['Team'] = 'IND'

# %%
ind_bat
# Out:
#             Player  Mat  Inns  NO  Runs   HS    Ave   BF      SR  100  50  0  \
# 0          V Kohli    6     6   3   296  82*  98.66  217  136.40    0   4  0
# 1         SA Yadav    6     6   2   239   68  59.75  126  189.68    0   3  0
# 2        HH Pandya    6     5   0   128   63  25.60   97  131.95    0   1  0
# 3         KL Rahul    6     6   0   128   51  21.33  106  120.75    0   2  0
# 4        RG Sharma    6     6   0   116   53  19.33  109  106.42    0   1  0
# 5         R Ashwin    6     4   3    21  13*  21.00   18  116.66    0   0  0
# 6       KD Karthik    4     3   0    14    7   4.66   22   63.63    0   0  0
# 7          RR Pant    2     2   0     9    6   4.50    9  100.00    0   0  0
# 8         AR Patel    5     3   1     9    7   4.50    9  100.00    0   0  0
# 9          B Kumar    6     1   1     4   4*      -    6   66.66    0   0  0
# 10  Arshdeep Singh    6     1   1     2   2*      -    1  200.00    0   0  0
# ...

# %%
ind_bat.drop([9,10,11,12],axis = 0, inplace = True)

# %%
ind_bat
# Out:
#        Player  Mat  Inns  NO  Runs   HS    Ave   BF      SR  100  50  0  4s  \
# 0     V Kohli    6     6   3   296  82*  98.66  217  136.40    0   4  0  25
# 1    SA Yadav    6     6   2   239   68  59.75  126  189.68    0   3  0  26
# 2   HH Pandya    6     5   0   128   63  25.60   97  131.95    0   1  0   7
# 3    KL Rahul    6     6   0   128   51  21.33  106  120.75    0   2  0   8
# 4   RG Sharma    6     6   0   116   53  19.33  109  106.42    0   1  0  11
# 5    R Ashwin    6     4   3    21  13*  21.00   18  116.66    0   0  0   1
# 6  KD Karthik    4     3   0    14    7   4.66   22   63.63    0   0  0   1
# 7     RR Pant    2     2   0     9    6   4.50    9  100.00    0   0  0   1
# 8    AR Patel    5     3   1     9    7   4.50    9  100.00    0   0  0   1
#
#    6s Team
# 0   8  IND
# 1   9  IND
# 2   7  IND
# 3   8  IND
# 4   4  IND
# 5   1  IND
# 6   0  IND
# 7   0  IND
# 8   0  IND

# %%
ind_bat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  9 non-null      object
#  1   Mat     9 non-null      int64
#  2   Inns    9 non-null      int64
#  3   NO      9 non-null      int64
#  4   Runs    9 non-null      int64
#  5   HS      9 non-null      object
#  6   Ave     9 non-null      object
#  7   BF      9 non-null      int64
#  8   SR      9 non-null      float64
#  9   100     9 non-null      int64
#  10  50      9 non-null      int64
#  11  0       9 non-null      int64
#  12  4s      9 non-null      int64
#  13  6s      9 non-null      int64
#  14  Team    9 non-null      object
# dtypes: float64(1), int64(10), object(4)
# memory usage: 1.2+ KB

# %%
new_col = ind_bat['HS'].str.replace('*','',regex = True)

# %%
ind_bat['HS'] = new_col

# %%
ind_bat
# Out:
#        Player  Mat  Inns  NO  Runs  HS    Ave   BF      SR  100  50  0  4s  \
# 0     V Kohli    6     6   3   296  82  98.66  217  136.40    0   4  0  25
# 1    SA Yadav    6     6   2   239  68  59.75  126  189.68    0   3  0  26
# 2   HH Pandya    6     5   0   128  63  25.60   97  131.95    0   1  0   7
# 3    KL Rahul    6     6   0   128  51  21.33  106  120.75    0   2  0   8
# 4   RG Sharma    6     6   0   116  53  19.33  109  106.42    0   1  0  11
# 5    R Ashwin    6     4   3    21  13  21.00   18  116.66    0   0  0   1
# 6  KD Karthik    4     3   0    14   7   4.66   22   63.63    0   0  0   1
# 7     RR Pant    2     2   0     9   6   4.50    9  100.00    0   0  0   1
# 8    AR Patel    5     3   1     9   7   4.50    9  100.00    0   0  0   1
#
#    6s Team
# 0   8  IND
# 1   9  IND
# 2   7  IND
# 3   8  IND
# 4   4  IND
# 5   1  IND
# 6   0  IND
# 7   0  IND
# 8   0  IND

# %%
ind_bat['HS'] = ind_bat['HS'].astype("int64")
ind_bat['Ave'] = ind_bat['Ave'].astype("float64")

# %%
ind_bat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  9 non-null      object
#  1   Mat     9 non-null      int64
#  2   Inns    9 non-null      int64
#  3   NO      9 non-null      int64
#  4   Runs    9 non-null      int64
#  5   HS      9 non-null      int64
#  6   Ave     9 non-null      float64
#  7   BF      9 non-null      int64
#  8   SR      9 non-null      float64
#  9   100     9 non-null      int64
#  10  50      9 non-null      int64
#  11  0       9 non-null      int64
#  12  4s      9 non-null      int64
#  13  6s      9 non-null      int64
#  14  Team    9 non-null      object
# dtypes: float64(2), int64(11), object(2)
# memory usage: 1.2+ KB

# %%
import matplotlib.pyplot as plt
#import seaborn as sns 
#import plotly.express as px

# %%
ind_bat.head().plot(kind = 'bar',x = 'Player',y = 'Runs')

eng_bat.head().plot(kind = 'bar',x = 'Player',y = 'Runs' )
# Out:
# <AxesSubplot:xlabel='Player'>

# %%
#iris.head().T.plot(kind = 'pie',subplots = True,figsize = (20,20),layout = (2,3))

# %%
# Create the first subplot for England team

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(25, 10))
 # 1 row, 2 columns, first subplot
plt.subplot(1, 2, 1)
bars1 = eng_bat['Player'].head()
heights1 = eng_bat['Runs'].head()
plt.barh(bars1, heights1)
plt.xlabel('Player',fontsize=30)
plt.ylabel('Runs',fontsize=30)
plt.title('ENG_Batting',fontsize=40)

# increase font size of player names
ax1.tick_params(axis = 'y',labelsize=20)

# increase font size of scores
ax1.tick_params(axis = 'x',labelsize=20)


# Create the second subplot for India Team
plt.subplot(1, 2, 2)  # 1 row, 2 columns, second subplot
bars2 = ind_bat['Player'].head()
heights2 = ind_bat['Runs'].head()
plt.barh(bars2, heights2, color='orange',)
plt.xlabel('Player',fontsize=30)
plt.ylabel('Runs',fontsize=30)
plt.title('IND_Bat',fontsize=40)

# increase font size of player names
ax2.tick_params(axis = 'y',labelsize=20)

# increase font size of scores
ax2.tick_params(axis = 'x',labelsize=20)


# Adjust the layout and spacing of the subplots
plt.tight_layout()

# Show the plots
plt.show()

# %%
ind_bat[3:5]
# Out:
#       Player  Mat  Inns  NO  Runs  HS    Ave   BF      SR  100  50  0  4s  6s  \
# 3   KL Rahul    6     6   0   128  51  21.33  106  120.75    0   2  0   8   8
# 4  RG Sharma    6     6   0   116  53  19.33  109  106.42    0   1  0  11   4
#
#   Team
# 3  IND
# 4  IND

# %%
sr_ind = ind_bat.iloc[[3,4,0,1,7],[0,8]]

# %%
sr_eng = eng_bat.iloc[[0,1,2,5,3],[0,8]]

# %%
# Create the first subplot for England team

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(25, 10))
 # 1 row, 2 columns, first subplot
plt.subplot(1, 2, 1)
bars1 = sr_eng['Player']
heights1 = sr_eng['SR']
plt.bar(bars1, heights1)
plt.xlabel('TEAM-ENG',fontsize=30)
plt.ylabel('STRICK-RATE',fontsize=30)
#plt.title('STRIKE-RATE COMPARISON OF ENG VS IND PLAYERS',fontsize=40)
# to increase the scale of y axis 
plt.yticks(np.arange(0,220,20))

# increase font size of player names
ax1.tick_params(axis = 'y',labelsize=20)
# increase font size of scores
ax1.tick_params(axis = 'x',labelsize=20)


# Create the second subplot for India Team
plt.subplot(1, 2, 2)  # 1 row, 2 columns, second subplot
bars2 = sr_ind['Player']
heights2 = sr_ind['SR']
plt.bar(bars2, heights2, color='orange',)
plt.xlabel('TEAM INDIA',fontsize=30)
plt.ylabel('STRIKE-RATE',fontsize=30)
#plt.title('STRIKE-RATE COMPARISON OF IND',fontsize=40)

#common title for 3 graphs
fig.suptitle('Strike Rate Comparison ENGLAND VS INDIA', fontsize=30)
# to increase the scale of y axis 
plt.yticks(np.arange(0,220,20))  


# increase font size of player names
ax2.tick_params(axis = 'y',labelsize=20)
# increase font size of scores
ax2.tick_params(axis = 'x',labelsize=20)


# Adjust the layout and spacing of the subplots
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# AVERAGE OF INDIA AND ENGLAND

# %%
ind_batt = ind_bat.head()

# %%
eng_batt = eng_bat.head()

# %%
ind_batt
# Out:
#       Player  Mat  Inns  NO  Runs  HS    Ave   BF      SR  100  50  0  4s  6s  \
# 0    V Kohli    6     6   3   296  82  98.66  217  136.40    0   4  0  25   8
# 1   SA Yadav    6     6   2   239  68  59.75  126  189.68    0   3  0  26   9
# 2  HH Pandya    6     5   0   128  63  25.60   97  131.95    0   1  0   7   7
# 3   KL Rahul    6     6   0   128  51  21.33  106  120.75    0   2  0   8   8
# 4  RG Sharma    6     6   0   116  53  19.33  109  106.42    0   1  0  11   4
#
#   Team
# 0  IND
# 1  IND
# 2  IND
# 3  IND
# 4  IND

# %%
eng_batt
# Out:
#        Player  Mat  Inns  NO  Runs  HS    Ave   BF      SR  100  50  0  4s  \
# 0  JC Buttler    6     6   1   225  80  45.00  156  144.23    0   2  1  24
# 1    AD Hales    6     6   1   212  86  42.40  144  147.22    0   2  0  19
# 2   BA Stokes    6     5   2   110  52  36.66  104  105.76    0   1  0   7
# 3      MM Ali    6     5   2    57  24  19.00   46  123.91    0   0  0   6
# 4    DJ Malan    4     3   1    56  35  28.00   68   82.35    0   0  0   2
#
#    6s Team
# 0   7  ENG
# 1  10  ENG
# 2   1  ENG
# 3   1  ENG
# 4   0  ENG

# %%
combine_ind_eng_batt_ave = pd.concat([eng_batt[['Player','Ave','Team']],ind_batt[['Player','Ave','Team']]],axis = 0)

# %%
combine_batt_ave = combine_ind_eng_batt_ave.sort_values(ascending = False,by = 'Ave').sort_index()

# %%
#top_10_sr = top_10_sr_bow.sort_values(ascending = False,by = 'SR')

# %%
combine_batt_ave
# Out:
#        Player    Ave Team
# 0     V Kohli  98.66  IND
# 0  JC Buttler  45.00  ENG
# 1    SA Yadav  59.75  IND
# 1    AD Hales  42.40  ENG
# 2   BA Stokes  36.66  ENG
# 2   HH Pandya  25.60  IND
# 3    KL Rahul  21.33  IND
# 3      MM Ali  19.00  ENG
# 4    DJ Malan  28.00  ENG
# 4   RG Sharma  19.33  IND

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x="Player", y="Ave",
            hue="Team", data=combine_batt_ave.head(10),
            palette='Reds')
  
plt.ylabel("Average", size=14)
plt.xlabel("Players", size=14)
plt.title("BATTING AVERAGE OF IND & ENG", size=18)
# Out:
# Text(0.5, 1.0, 'BATTING AVERAGE OF IND & ENG')

# %%
import numpy as np

# %%
most_wick = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/bowling/most_wickets_career.html?id=14450;team=6;type=tournament')

# %%
most_wic = most_wick[0]

# %%
most_wic
# Out:
#            Player  Mat  Inns  Overs  Mdns  Runs  Wkts   BBI    Ave  Econ  \
# 0  Arshdeep Singh    6     6   20.0     0   156    10  3/32  15.60  7.80
# 1       HH Pandya    6     6   18.0     0   146     8  3/30  18.25  8.11
# 2  Mohammed Shami    6     6   20.0     0   143     6  2/14  23.83  7.15
# 3        R Ashwin    6     6   19.0     0   155     6  3/22  25.83  8.15
# 4         B Kumar    6     6   18.4     3   115     4   2/9  28.75  6.16
# 5        AR Patel    5     5   13.2     0   115     3  2/18  38.33  8.62
#
#      SR  4  5
# 0  12.0  0  0
# 1  13.5  0  0
# 2  20.0  0  0
# 3  19.0  0  0
# 4  28.0  0  0
# 5  26.6  0  0

# %%
best_eco = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/bowling/best_career_economy_rate.html?id=14450;team=6;type=tournament')

# %%
best_eco = best_eco[0]

# %%
best_eco.drop(np.arange(6,13),axis = 0,inplace=True)

# %%
best_eco
# Out:
#            Player  Mat Overs Mdns Runs Wkts   BBI    Ave  Econ    SR  4  5
# 0         B Kumar    6  18.4    3  115    4   2/9  28.75  6.16  28.0  0  0
# 1  Mohammed Shami    6  20.0    0  143    6  2/14  23.83  7.15  20.0  0  0
# 2  Arshdeep Singh    6  20.0    0  156   10  3/32  15.60  7.80  12.0  0  0
# 3       HH Pandya    6  18.0    0  146    8  3/30  18.25  8.11  13.5  0  0
# 4        R Ashwin    6  19.0    0  155    6  3/22  25.83  8.15  19.0  0  0
# 5        AR Patel    5  13.2    0  115    3  2/18  38.33  8.62  26.6  0  0

# %%
best_sr = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/bowling/best_career_strike_rate.html?id=14450;team=6;type=tournament')

# %%
best_sr = best_sr[0]

# %%
best_sr.drop(np.arange(6,13),axis=0,inplace=True)

# %%
best_sr
# Out:
#            Player  Mat Overs Mdns Runs Wkts   BBI    Ave  Econ    SR  4  5
# 0  Arshdeep Singh    6  20.0    0  156   10  3/32  15.60  7.80  12.0  0  0
# 1       HH Pandya    6  18.0    0  146    8  3/30  18.25  8.11  13.5  0  0
# 2        R Ashwin    6  19.0    0  155    6  3/22  25.83  8.15  19.0  0  0
# 3  Mohammed Shami    6  20.0    0  143    6  2/14  23.83  7.15  20.0  0  0
# 4        AR Patel    5  13.2    0  115    3  2/18  38.33  8.62  26.6  0  0
# 5         B Kumar    6  18.4    3  115    4   2/9  28.75  6.16  28.0  0  0

# %%
most_wic
# Out:
#            Player  Mat  Inns  Overs  Mdns  Runs  Wkts   BBI    Ave  Econ  \
# 0  Arshdeep Singh    6     6   20.0     0   156    10  3/32  15.60  7.80
# 1       HH Pandya    6     6   18.0     0   146     8  3/30  18.25  8.11
# 2  Mohammed Shami    6     6   20.0     0   143     6  2/14  23.83  7.15
# 3        R Ashwin    6     6   19.0     0   155     6  3/22  25.83  8.15
# 4         B Kumar    6     6   18.4     3   115     4   2/9  28.75  6.16
# 5        AR Patel    5     5   13.2     0   115     3  2/18  38.33  8.62
#
#      SR  4  5
# 0  12.0  0  0
# 1  13.5  0  0
# 2  20.0  0  0
# 3  19.0  0  0
# 4  28.0  0  0
# 5  26.6  0  0

# %%
most_wic.drop(['Mdns','4','5'],axis = 1,inplace = True)

# %%
most_wic.drop(['BBI'],axis=1,inplace=True)

# %%
most_wic
# Out:
#            Player  Mat  Inns  Overs  Runs  Wkts    Ave  Econ    SR
# 0  Arshdeep Singh    6     6   20.0   156    10  15.60  7.80  12.0
# 1       HH Pandya    6     6   18.0   146     8  18.25  8.11  13.5
# 2  Mohammed Shami    6     6   20.0   143     6  23.83  7.15  20.0
# 3        R Ashwin    6     6   19.0   155     6  25.83  8.15  19.0
# 4         B Kumar    6     6   18.4   115     4  28.75  6.16  28.0
# 5        AR Patel    5     5   13.2   115     3  38.33  8.62  26.6

# %%
#most_wick.info()

# %%
#best_eco.drop(['Mdns','4','5'],axis = 1,inplace = True)

# %%
best_eco.drop(['BBI'],axis=1,inplace=True)

# %%
best_eco
# Out:
#             Player  Mat Overs Mdns Runs Wkts    Ave  Econ    SR  4  5
# 0          B Kumar    6  18.4    3  115    4  28.75  6.16  28.0  0  0
# 1   Mohammed Shami    6  20.0    0  143    6  23.83  7.15  20.0  0  0
# 2   Arshdeep Singh    6  20.0    0  156   10  15.60  7.80  12.0  0  0
# 3        HH Pandya    6  18.0    0  146    8  18.25  8.11  13.5  0  0
# 4         R Ashwin    6  19.0    0  155    6  25.83  8.15  19.0  0  0
# 5         AR Patel    5  13.2    0  115    3  38.33  8.62  26.6  0  0
# 6         DJ Hooda    1     -    -    -    -      -     -     -  -  -
# 7       KD Karthik    4     -    -    -    -      -     -     -  -  -
# 8          V Kohli    6     -    -    -    -      -     -     -  -  -
# 9          RR Pant    2     -    -    -    -      -     -     -  -  -
# 10        KL Rahul    6     -    -    -    -      -     -     -  -  -
# 11       RG Sharma    6     -    -    -    -      -     -     -  -  -
# ...

# %%
#best_eco.info()

# %%
best_eco['Overs'] = best_eco['Overs'].astype("float64")
best_eco['Ave'] = best_eco['Ave'].astype("float64")
best_eco['Econ'] = best_eco['Econ'].astype("float64")
best_eco['SR'] = best_eco['SR'].astype("float64")

best_eco = best_eco.astype({'Runs':'int64','Wkts':'int64'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 best_eco['Overs'] = best_eco['Overs'].astype("float64")
#       2 best_eco['Ave'] = best_eco['Ave'].astype("float64")
#       3 best_eco['Econ'] = best_eco['Econ'].astype("float64")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# ...

# %%
best_sr.drop(['Mdns','4','5'],axis = 1,inplace = True)

# %%
best_sr.drop(['BBI'],axis=1,inplace=True)

# %%
best_sr['Overs'] = best_sr['Overs'].astype("float64")
best_sr['Ave'] = best_sr['Ave'].astype("float64")
best_sr = best_sr.astype({'Runs':'int64','Wkts':'int64'})

# %%
#best_sr.info()

# %% [markdown]
# England Data

# %%
most_wick_eng = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/bowling/most_wickets_career.html?id=14450;team=1;type=tournament')

# %%
most_wick_eng[0].drop(7,axis = 0,inplace = True)

# %%
most_wick_eng = most_wick_eng[0]

# %%
most_wick_eng
# Out:
#            Player  Mat  Inns  Overs  Mdns  Runs  Wkts   BBI    Ave  Econ  \
# 0       SM Curran    6     6   22.4     0   148    13  5/10  11.38  6.52
# 1         MA Wood    4     4   14.0     0   108     9  3/26  12.00  7.71
# 2       BA Stokes    6     6   16.2     0   111     6  2/19  18.50  6.79
# 3       CJ Jordan    2     2    8.0     0    70     5  3/43  14.00  8.75
# 4       CR Woakes    6     6   20.0     0   172     5  2/33  34.40  8.60
# 5       AU Rashid    6     6   24.0     1   147     4  2/22  36.75  6.12
# 6  LS Livingstone    6     5   12.0     0    96     3  3/17  32.00  8.00
#
#      SR  4  5
# 0  10.4  0  1
# 1   9.3  0  0
# 2  16.3  0  0
# 3   9.6  0  0
# 4  24.0  0  0
# 5  36.0  0  0
# 6  24.0  0  0

# %%
most_wick_eng.drop(['Mdns','4','5','BBI'],axis = 1,inplace = True)

# %%
most_wick_eng
# Out:
#            Player  Mat  Inns  Overs  Runs  Wkts    Ave  Econ    SR
# 0       SM Curran    6     6   22.4   148    13  11.38  6.52  10.4
# 1         MA Wood    4     4   14.0   108     9  12.00  7.71   9.3
# 2       BA Stokes    6     6   16.2   111     6  18.50  6.79  16.3
# 3       CJ Jordan    2     2    8.0    70     5  14.00  8.75   9.6
# 4       CR Woakes    6     6   20.0   172     5  34.40  8.60  24.0
# 5       AU Rashid    6     6   24.0   147     4  36.75  6.12  36.0
# 6  LS Livingstone    6     5   12.0    96     3  32.00  8.00  24.0

# %%
most_wick_eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  7 non-null      object
#  1   Mat     7 non-null      int64
#  2   Inns    7 non-null      int64
#  3   Overs   7 non-null      float64
#  4   Runs    7 non-null      int64
#  5   Wkts    7 non-null      int64
#  6   Ave     7 non-null      object
#  7   Econ    7 non-null      float64
#  8   SR      7 non-null      object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 632.0+ bytes

# %%
most_wick_eng['Ave'] = most_wick_eng['Ave'].astype("float64")
most_wick_eng['SR'] = most_wick_eng['SR'].astype("float64")

# %%
best_eco_eng = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/bowling/best_career_economy_rate.html?id=14450;team=1;type=tournament')

# %%
best_eco_eng = best_eco_eng[0]

# %%
best_eco_eng
# Out:
#             Player  Mat Overs Mdns Runs Wkts   BBI    Ave  Econ    SR  4  5
# 0           MM Ali    6   2.0    0    9    0     -      -  4.50     -  0  0
# 1        AU Rashid    6  24.0    1  147    4  2/22  36.75  6.12  36.0  0  0
# 2        SM Curran    6  22.4    0  148   13  5/10  11.38  6.52  10.4  0  1
# 3        BA Stokes    6  16.2    0  111    6  2/19  18.50  6.79  16.3  0  0
# 4          MA Wood    4  14.0    0  108    9  3/26  12.00  7.71   9.3  0  0
# 5   LS Livingstone    6  12.0    0   96    3  3/17  32.00  8.00  24.0  0  0
# 6        CR Woakes    6  20.0    0  172    5  2/33  34.40  8.60  24.0  0  0
# 7        CJ Jordan    2   8.0    0   70    5  3/43  14.00  8.75   9.6  0  0
# 8         HC Brook    6     -    -    -    -     -      -     -     -  -  -
# 9       JC Buttler    6     -    -    -    -     -      -     -     -  -  -
# 10        AD Hales    6     -    -    -    -     -      -     -     -  -  -
# ...

# %%
best_eco_eng.drop(np.arange(8,13),axis = 0,inplace=True)

# %%
best_eco_eng.drop(12,axis=0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [173], in <cell line: 1>()
# ----> 1 best_eco_eng.drop(12,axis=0,inplace=True)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
# ...

# %%
best_eco_eng
# Out:
#            Player  Mat Overs Mdns Runs Wkts   BBI    Ave  Econ    SR  4  5
# 0          MM Ali    6   2.0    0    9    0     -      -  4.50     -  0  0
# 1       AU Rashid    6  24.0    1  147    4  2/22  36.75  6.12  36.0  0  0
# 2       SM Curran    6  22.4    0  148   13  5/10  11.38  6.52  10.4  0  1
# 3       BA Stokes    6  16.2    0  111    6  2/19  18.50  6.79  16.3  0  0
# 4         MA Wood    4  14.0    0  108    9  3/26  12.00  7.71   9.3  0  0
# 5  LS Livingstone    6  12.0    0   96    3  3/17  32.00  8.00  24.0  0  0
# 6       CR Woakes    6  20.0    0  172    5  2/33  34.40  8.60  24.0  0  0
# 7       CJ Jordan    2   8.0    0   70    5  3/43  14.00  8.75   9.6  0  0

# %%
best_eco_eng.drop(['Mdns','4','5','BBI'],axis = 1,inplace = True)

# %%
best_eco_eng
# Out:
#            Player  Mat Overs Runs Wkts    Ave  Econ    SR
# 0          MM Ali    6   2.0    9    0      -  4.50     -
# 1       AU Rashid    6  24.0  147    4  36.75  6.12  36.0
# 2       SM Curran    6  22.4  148   13  11.38  6.52  10.4
# 3       BA Stokes    6  16.2  111    6  18.50  6.79  16.3
# 4         MA Wood    4  14.0  108    9  12.00  7.71   9.3
# 5  LS Livingstone    6  12.0   96    3  32.00  8.00  24.0
# 6       CR Woakes    6  20.0  172    5  34.40  8.60  24.0
# 7       CJ Jordan    2   8.0   70    5  14.00  8.75   9.6

# %%
best_eco_eng.drop(0,axis=0,inplace=True)

# %%
best_eco_eng
# Out:
#            Player  Mat Overs Runs Wkts    Ave  Econ    SR
# 1       AU Rashid    6  24.0  147    4  36.75  6.12  36.0
# 2       SM Curran    6  22.4  148   13  11.38  6.52  10.4
# 3       BA Stokes    6  16.2  111    6  18.50  6.79  16.3
# 4         MA Wood    4  14.0  108    9  12.00  7.71   9.3
# 5  LS Livingstone    6  12.0   96    3  32.00  8.00  24.0
# 6       CR Woakes    6  20.0  172    5  34.40  8.60  24.0
# 7       CJ Jordan    2   8.0   70    5  14.00  8.75   9.6

# %%
#best_eco_eng.info()

# %%
best_eco_eng = best_eco_eng.astype({'Runs':'int64','Wkts':'int64'})
best_eco_eng['Overs'] = best_eco_eng['Overs'].astype("float64")
best_eco_eng['Ave'] = best_eco_eng['Ave'].astype("float64")
best_eco_eng['Econ'] = best_eco_eng['Econ'].astype("float64")
best_eco_eng['SR'] = best_eco_eng['SR'].astype("float64")

# %%
best_eco_eng
# Out:
#            Player  Mat  Overs  Runs  Wkts    Ave  Econ    SR
# 1       AU Rashid    6   24.0   147     4  36.75  6.12  36.0
# 2       SM Curran    6   22.4   148    13  11.38  6.52  10.4
# 3       BA Stokes    6   16.2   111     6  18.50  6.79  16.3
# 4         MA Wood    4   14.0   108     9  12.00  7.71   9.3
# 5  LS Livingstone    6   12.0    96     3  32.00  8.00  24.0
# 6       CR Woakes    6   20.0   172     5  34.40  8.60  24.0
# 7       CJ Jordan    2    8.0    70     5  14.00  8.75   9.6

# %%
best_sr_eng = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/bowling/best_career_strike_rate.html?id=14450;team=1;type=tournament')

# %%
best_sr_eng = best_sr_eng[0]

# %%
best_sr_eng.drop(np.arange(7,13),axis=0,inplace=True)

# %%
#best_sr_eng

# %%
best_sr_eng.drop(['Mdns','4','5','BBI'],axis = 1,inplace = True)

# %%
#best_sr_eng

# %%
#best_sr_eng.info()

# %%
best_sr_eng = best_sr_eng.astype({'Runs':'int64','Wkts':'int64'})
best_sr_eng['Overs'] = best_sr_eng['Overs'].astype("float64")
best_sr_eng['Ave'] = best_sr_eng['Ave'].astype("float64")
best_sr_eng['Econ'] = best_sr_eng['Econ'].astype("float64")
best_sr_eng['SR'] = best_sr_eng['SR'].astype("float64")

# %%
most_wic.to_csv('india wicket')

# %%
most_wic_eng.to_csv('england wicket')

# %%
most_wic['Team'] = 'IND'

# %%
most_wic
# Out:
#            Player  Mat  Inns  Overs  Runs  Wkts    Ave  Econ    SR Team
# 0  Arshdeep Singh    6     6   20.0   156    10  15.60  7.80  12.0  IND
# 1       HH Pandya    6     6   18.0   146     8  18.25  8.11  13.5  IND
# 2  Mohammed Shami    6     6   20.0   143     6  23.83  7.15  20.0  IND
# 3        R Ashwin    6     6   19.0   155     6  25.83  8.15  19.0  IND
# 4         B Kumar    6     6   18.4   115     4  28.75  6.16  28.0  IND
# 5        AR Patel    5     5   13.2   115     3  38.33  8.62  26.6  IND

# %%
most_wick_eng['Team'] = 'ENG'

# %%
most_wick_eng
# Out:
#            Player  Mat  Inns  Overs  Runs  Wkts    Ave  Econ    SR Team
# 0       SM Curran    6     6   22.4   148    13  11.38  6.52  10.4  ENG
# 1         MA Wood    4     4   14.0   108     9  12.00  7.71   9.3  ENG
# 2       BA Stokes    6     6   16.2   111     6  18.50  6.79  16.3  ENG
# 3       CJ Jordan    2     2    8.0    70     5  14.00  8.75   9.6  ENG
# 4       CR Woakes    6     6   20.0   172     5  34.40  8.60  24.0  ENG
# 5       AU Rashid    6     6   24.0   147     4  36.75  6.12  36.0  ENG
# 6  LS Livingstone    6     5   12.0    96     3  32.00  8.00  24.0  ENG

# %%
combine_most_wick = pd.concat([most_wick_eng[['Player','Wkts','Team']],most_wic[['Player','Wkts','Team']]],axis = 0)

# %%
top_10_bowler = combine_most_wick.sort_values(by='Wkts',ascending = False)

# %%
top_10_bowler
# Out:
#            Player  Wkts Team
# 0       SM Curran    13  ENG
# 0  Arshdeep Singh    10  IND
# 1         MA Wood     9  ENG
# 1       HH Pandya     8  IND
# 2       BA Stokes     6  ENG
# 2  Mohammed Shami     6  IND
# 3        R Ashwin     6  IND
# 3       CJ Jordan     5  ENG
# 4       CR Woakes     5  ENG
# 5       AU Rashid     4  ENG
# 4         B Kumar     4  IND
# 6  LS Livingstone     3  ENG
# 5        AR Patel     3  IND

# %%
top_10 = top_10_bowler.reset_index().drop('index',axis = 1)

# %%
top_10.head(10)
# Out:
#            Player  Wkts Team
# 0       SM Curran    13  ENG
# 1  Arshdeep Singh    10  IND
# 2         MA Wood     9  ENG
# 3       HH Pandya     8  IND
# 4       BA Stokes     6  ENG
# 5  Mohammed Shami     6  IND
# 6        R Ashwin     6  IND
# 7       CJ Jordan     5  ENG
# 8       CR Woakes     5  ENG
# 9       AU Rashid     4  ENG

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (20,10))
sns.set_theme(style="whitegrid")
#sns.barplot(x="Player", y="Wkts", data=top_10.head(10), capsize=.2)


sns.barplot(data = top_10.head(10),x = 'Player',y = 'Wkts',hue = 'Team',palette = 'Blues')
plt.ylabel("Wickets", size=30)
plt.xlabel("Players", size=30)
plt.title("Wickets By Top 10 Bowlers", size=30)
# Out:
# Text(0.5, 1.0, 'Wickets By Top 10 Bowlers')

# %% [markdown]
# BOWLER STRIKE RATE CAMPARISON

# %% [markdown]
# TABLES - BEST_ECO_ENG.BEST_ECO

# %%
best_eco['Team'] = 'IND'

# %%
best_eco
# Out:
#            Player  Mat Overs Mdns Runs Wkts   BBI    Ave  Econ    SR  4  5  \
# 0         B Kumar    6  18.4    3  115    4   2/9  28.75  6.16  28.0  0  0
# 1  Mohammed Shami    6  20.0    0  143    6  2/14  23.83  7.15  20.0  0  0
# 2  Arshdeep Singh    6  20.0    0  156   10  3/32  15.60  7.80  12.0  0  0
# 3       HH Pandya    6  18.0    0  146    8  3/30  18.25  8.11  13.5  0  0
# 4        R Ashwin    6  19.0    0  155    6  3/22  25.83  8.15  19.0  0  0
# 5        AR Patel    5  13.2    0  115    3  2/18  38.33  8.62  26.6  0  0
#
#   Team
# 0  IND
# 1  IND
# 2  IND
# 3  IND
# 4  IND
# 5  IND

# %%
best_eco_eng['Team'] = 'ENG'

# %%
best_eco_eng
# Out:
#            Player  Mat  Overs  Runs  Wkts    Ave  Econ    SR Team
# 1       AU Rashid    6   24.0   147     4  36.75  6.12  36.0  ENG
# 2       SM Curran    6   22.4   148    13  11.38  6.52  10.4  ENG
# 3       BA Stokes    6   16.2   111     6  18.50  6.79  16.3  ENG
# 4         MA Wood    4   14.0   108     9  12.00  7.71   9.3  ENG
# 5  LS Livingstone    6   12.0    96     3  32.00  8.00  24.0  ENG
# 6       CR Woakes    6   20.0   172     5  34.40  8.60  24.0  ENG
# 7       CJ Jordan    2    8.0    70     5  14.00  8.75   9.6  ENG

# %%
combine_eco = pd.concat([best_eco_eng[['Player','Econ','Team']],best_eco[['Player','Econ','Team']]],axis = 0)

# %%
top_10_eco_bowl = combine_eco.sort_values(by ='Econ',ascending = True).sort_index()

# %%
combine_eco['Econ'] = combine_eco['Econ'].astype('float64')

# %%
top_10_eco_bowl
# Out:
#            Player  Econ Team
# 0         B Kumar  6.16  IND
# 1       AU Rashid  6.12  ENG
# 1  Mohammed Shami  7.15  IND
# 2       SM Curran  6.52  ENG
# 2  Arshdeep Singh  7.80  IND
# 3       BA Stokes  6.79  ENG
# 3       HH Pandya  8.11  IND
# 4         MA Wood  7.71  ENG
# 4        R Ashwin  8.15  IND
# 5  LS Livingstone  8.00  ENG
# 5        AR Patel  8.62  IND
# 6       CR Woakes  8.60  ENG
# 7       CJ Jordan  8.75  ENG

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x="Player", y="Econ",
            hue="Team", data=top_10_eco_bowl.head(10),
            palette='Greens')
  
plt.ylabel("Economy", size=14)
plt.xlabel("Players", size=14)
plt.title("Economy By Top 10 Bowlers", size=18)
# Out:
# Text(0.5, 1.0, 'Economy By Top 10 Bowlers')

# %%
best_sr["Team"] ='IND'

# %%
best_sr_eng["Team"] = 'ENG'

# %%
combine_sr = pd.concat([best_sr_eng[['Player','SR','Team']],best_sr[['Player','SR','Team']]],axis = 0)

# %%
top_10_sr_bow = combine_sr.sort_index()

# %%
top_10_sr = top_10_sr_bow.sort_values(ascending = False,by = 'SR')

# %%
top_10_sr
# Out:
#            Player    SR Team
# 6       AU Rashid  36.0  ENG
# 5         B Kumar  28.0  IND
# 4        AR Patel  26.6  IND
# 4       CR Woakes  24.0  ENG
# 5  LS Livingstone  24.0  ENG
# 3  Mohammed Shami  20.0  IND
# 2        R Ashwin  19.0  IND
# 3       BA Stokes  16.3  ENG
# 1       HH Pandya  13.5  IND
# 0  Arshdeep Singh  12.0  IND
# 2       SM Curran  10.4  ENG
# 1       CJ Jordan   9.6  ENG
# 0         MA Wood   9.3  ENG

# %%
top_10_sr_bow["SR"] = top_10_sr_bow["SR"].astype("float64")

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x="Player", y="SR",
            hue="Team", data=top_10_sr.head(10),
            palette='Reds')
  
plt.ylabel("Strike Rate", size=14)
plt.xlabel("Players", size=14)
plt.title("Strike Rate By Top 10 Bowlers", size=18)
# Out:
# Text(0.5, 1.0, 'Strike Rate By Top 10 Bowlers')

# %%
g1= pd.read_html('https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/india-vs-pakistan-16th-match-group-2-1298150/full-scorecard')

# %%
ground_bow = g1[1]

# %%
#ground.dropna(how='all')

# %%
ground_bow
# Out:
#                BOWLING  O  M   R  W   ECON  0s 4s 6s WD NB
# 0    Bhuvneshwar Kumar  4  0  22  1   5.50  17  1  1  3  0
# 2       Arshdeep Singh  4  0  32  3   8.00  10  3  1  1  0
# 4       Mohammed Shami  4  0  25  1   6.25  14  4  0  1  0
# 6        Hardik Pandya  4  0  30  3   7.50  10  4  0  0  0
# 8  Ravichandran Ashwin  3  0  23  0   7.66   5  0  1  1  0
# 9           Axar Patel  1  0  21  0  21.00   2  0  3  0  0

# %%
for i in range(1,8,2):
    ground_bow.drop(i,axis=0,inplace=True)

# %%
ground_bow
# Out:
#                BOWLING  O  M   R  W   ECON  0s 4s 6s WD NB
# 0    Bhuvneshwar Kumar  4  0  22  1   5.50  17  1  1  3  0
# 2       Arshdeep Singh  4  0  32  3   8.00  10  3  1  1  0
# 4       Mohammed Shami  4  0  25  1   6.25  14  4  0  1  0
# 6        Hardik Pandya  4  0  30  3   7.50  10  4  0  0  0
# 8  Ravichandran Ashwin  3  0  23  0   7.66   5  0  1  1  0
# 9           Axar Patel  1  0  21  0  21.00   2  0  3  0  0

# %%
ground_pak_bat = g1[0]

# %%
ground_pak_bat.dropna(how = 'all',inplace=True)

# %%
ground_pak_bat
# Out:
#                 BATTING                   Unnamed: 1   R   B    M 4s 6s  \
# 0     Mohammad Rizwan †     c Kumar b Arshdeep Singh   4  12   25  1  0
# 2        Babar Azam (c)         lbw b Arshdeep Singh   0   1   10  0  0
# 4           Shan Masood                      not out  52  42  101  5  0
# 5        Iftikhar Ahmed         lbw b Mohammed Shami  51  34   43  2  4
# 7           Shadab Khan             c Yadav b Pandya   5   6    6  1  0
# 9            Haider Ali             c Yadav b Pandya   2   4    6  0  0
# 11       Mohammad Nawaz          c †Karthik b Pandya   9   6   12  2  0
# 13             Asif Ali  c †Karthik b Arshdeep Singh   2   3    6  0  0
# 15  Shaheen Shah Afridi                  c & b Kumar  16   8   17  1  1
# 17           Haris Rauf                      not out   6   4    3  0  1
#
#         SR Unnamed: 8  Unnamed: 9
# 0    33.33        NaN         NaN
# 2     0.00        NaN         NaN
# 4   123.80        NaN         NaN
# 5   150.00        NaN         NaN
# ...

# %%
#ground_pak_bat.drop([18,19,20,21],axis=0,inplace=True)

# %%
ground_pak_bat = ground_pak_bat.drop(['Unnamed: 8','Unnamed: 9'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [288], in <cell line: 1>()
# ----> 1 ground_pak_bat = ground_pak_bat.drop(['Unnamed: 8','Unnamed: 9'],axis=1)
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
ground_pak_bat

# %%
g5 = g5.drop(g5[["Unnamed: 1","Unnamed: 8","Unnamed: 9"]],axis= 1)
